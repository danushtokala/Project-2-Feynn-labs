# %%
import numpy as np #used for creating and manipulating arrays.
import pandas as pd #used for creating Series and DataFrames
import matplotlib.pyplot as plt #used for data visualization
import seaborn as sns #used for data visualization

# %%
df=pd.read_csv('C:\\Users\\Dhanush Thokala\\Downloads\\Indian_cities.csv')
df.head()
# Out:
#   name_of_city  state_code      state_name  dist_code  population_total  \
# 0      Abohar            3          PUNJAB          9            145238
# 1    Achalpur           27     MAHARASHTRA          7            112293
# 2    Adilabad           28  ANDHRA PRADESH          1            117388
# 3   Adityapur           20       JHARKHAND         24            173988
# 4       Adoni           28  ANDHRA PRADESH         21            166537
#
#    population_male  population_female  0-6_population_total  \
# 0            76840              68398                 15870
# 1            58256              54037                 11810
# 2            59232              58156                 13103
# 3            91495              82493                 23042
# 4            82743              83794                 18406
#
#    0-6_population_male  0-6_population_female  ...  sex_ratio  \
# 0                 8587                   7283  ...        890
# ...

# %%
df.shape
# Out:
# (493, 23)

# %%
#let's check the info of the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 493 entries, 0 to 492
# Data columns (total 23 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   name_of_city                    493 non-null    object
#  1   state_code                      493 non-null    int64
#  2   state_name                      493 non-null    object
#  3   dist_code                       493 non-null    int64
#  4   population_total                493 non-null    int64
#  5   population_male                 493 non-null    int64
#  6   population_female               493 non-null    int64
#  7   0-6_population_total            493 non-null    int64
#  8   0-6_population_male             493 non-null    int64
#  9   0-6_population_female           493 non-null    int64
#  10  literates_total                 493 non-null    int64
#  11  literates_male                  493 non-null    int64
# ...

# %% [markdown]
# As there are no null values in the dataset we can proceed further.

# %% [markdown]
# # Numerical and Categorical column division

# %%
numerical_cols=df._get_numeric_data().columns
numerical_cols
# Out:
# Index(['state_code', 'dist_code', 'population_total', 'population_male',
#        'population_female', '0-6_population_total', '0-6_population_male',
#        '0-6_population_female', 'literates_total', 'literates_male',
#        'literates_female', 'sex_ratio', 'child_sex_ratio',
#        'effective_literacy_rate_total', 'effective_literacy_rate_male',
#        'effective_literacy_rate_female', 'total_graduates', 'male_graduates',
#        'female_graduates', 'age'],
#       dtype='object')

# %%
categorical_cols=df.drop(numerical_cols,axis=1).columns
categorical_cols
# Out:
# Index(['name_of_city', 'state_name', 'location'], dtype='object')

# %%
df.describe()
# Out:
#        state_code   dist_code  population_total  population_male  \
# count  493.000000  493.000000      4.930000e+02     4.930000e+02
# mean    18.643002   16.782961      4.481124e+05     2.343468e+05
# std      9.297168   15.566131      1.033228e+06     5.487786e+05
# min      1.000000    1.000000      1.000360e+05     5.020100e+04
# 25%      9.000000    7.000000      1.261420e+05     6.638400e+04
# 50%     19.000000   13.000000      1.841330e+05     9.665500e+04
# 75%     27.000000   21.000000      3.490330e+05     1.750550e+05
# max     35.000000   99.000000      1.247845e+07     6.736815e+06
#
#        population_female  0-6_population_total  0-6_population_male  \
# count       4.930000e+02          4.930000e+02           493.000000
# mean        2.137656e+05          4.709285e+04         24849.527383
# std         4.848622e+05          1.050279e+05         55535.310272
# min         4.512600e+04          6.547000e+03          3406.000000
# ...

# %%
df.corr()
# Out:
#                                 state_code  dist_code  population_total  \
# state_code                        1.000000  -0.088946          0.054953
# dist_code                        -0.088946   1.000000          0.318398
# population_total                  0.054953   0.318398          1.000000
# population_male                   0.048442   0.319937          0.999647
# population_female                 0.062276   0.316385          0.999547
# 0-6_population_total              0.030726   0.318881          0.991590
# 0-6_population_male               0.025069   0.318189          0.989977
# 0-6_population_female             0.037050   0.319461          0.992786
# literates_total                   0.068414   0.315055          0.998777
# literates_male                    0.060318   0.316732          0.998561
# literates_female                  0.078278   0.312612          0.997831
# sex_ratio                         0.647582  -0.071230         -0.127811
# ...

# %% [markdown]
# # Descriptive Analysis

# %%
plt.figure(figsize=(10,8))
sns.heatmap(df.corr())
plt.show()

# %%
plt.figure(figsize=(10,8))
df['name_of_city'].value_counts().head(40).plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
plt.hist(df['age'],color='Teal',edgecolor='white')
plt.xlabel('age')
plt.ylabel('No. of customers')
plt.show()

# %%
plt.figure(figsize=(10,8))
df['state_name'].value_counts().plot(kind='barh',color='red')
# Out:
# <AxesSubplot:>

# %%
plt.scatter(df['effective_literacy_rate_male'],df['effective_literacy_rate_total'])

# %%
plt.scatter(df['effective_literacy_rate_female'],df['effective_literacy_rate_total'],color='green')

# %%
plt.scatter(df['population_male'],df['population_total'])

# %%
plt.scatter(df['population_female'],df['population_total'],color='green')

# %%
plt.scatter(df['male_graduates'],df['total_graduates'])
plt.scatter(df['female_graduates'],df['total_graduates'])

# %% [markdown]
# # Data Preprocessing

# %%
categorical_cols
# Out:
# Index(['name_of_city', 'state_name', 'location'], dtype='object')

# %%
# we may drop the location column as the city, statecode and statename is already mentioned.
df.drop('location',axis=1,inplace=True)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
df['name_of_city']=le.fit_transform(df['name_of_city'])
df['state_name']=le.fit_transform(df['state_name'])

# %%
df.head()
# Out:
#    name_of_city  state_code  state_name  dist_code  population_total  \
# 0             0           3          22          9            145238
# 1             1          27          14          7            112293
# 2             2          28           1          1            117388
# 3             3          20          10         24            173988
# 4             4          28           1         21            166537
#
#    population_male  population_female  0-6_population_total  \
# 0            76840              68398                 15870
# 1            58256              54037                 11810
# 2            59232              58156                 13103
# 3            91495              82493                 23042
# 4            82743              83794                 18406
#
#    0-6_population_male  0-6_population_female  ...  literates_female  \
# 0                 8587                   7283  ...             44972
# ...
